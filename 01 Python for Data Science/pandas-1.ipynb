# %% [markdown]
# # Pandas Complete Guide
#
# Comprehensive guide to Pandas - the most important library for data manipulation and analysis in Python.
#
# ## Table of Contents
#
# * [Introduction](#introduction)
# * [Series and DataFrames](#series-and-dataframes)
# * [DataFrame Basics and Inspection](#dataframe-basics-and-inspection)
# * [Reading and Writing Data](#reading-and-writing-data)
# * [Data Selection and Filtering](#data-selection-and-filtering)
# * [Data Cleaning](#data-cleaning)
# * [Sorting and Basic Statistics](#sorting-and-basic-statistics)
# * [Grouping and Aggregation](#grouping-and-aggregation)
# * [Merging and Joining](#merging-and-joining)
# * [Time Series Operations](#time-series-operations)
# * [Advanced Tricks and Performance](#advanced-tricks-and-performance)
# * [Practice Exercises

# %% [markdown]
# ## Introduction
#
# ### What is Pandas?
#
# Pandas is a library for data manipulation and analysis. It provides:
#
# * **DataFrame**: 2D labeled data structure (like Excel spreadsheet)
# * **Series**: 1D labeled array
# * **Powerful tools**: For cleaning, transforming, and analyzing data
#
# ### Why Pandas?
#
# * **Easy data manipulation**: Load, clean, transform data easily
# * **Handles missing data**: Built-in functions for dealing with NaN
# * **Time series**: Excellent support for time-based data
# * **Integration**: Works seamlessly with NumPy, Matplotlib, Scikit-learn

# %% [markdown]
# ### Installation

# %%
# pip install pandas

import pandas as pd
import numpy as np
print('Pandas version: ', pd.__version__)
print('Numpy version: ', np.__version__)
# Out:
# Pandas version:  3.0.2
# Numpy version:  2.4.4

# %% [markdown]
# ## Series and DataFrames
#
# ### Series
#
# A Series is a one-dimensional labeled array.

# %%
# Creating Series
s = pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# With custom index
s = pd.Series([10, 20, 30], index=['a','b','c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# From dictionary
s = pd.Series({
    'Alice':25,
    'Bob':30,
    'Charlie':35
})
print(s)
# Out:
# Alice      25
# Bob        30
# Charlie    35
# dtype: int64

# %% [markdown]
# DataFrame
#
# A DataFrame is a 2D labeled data structure with columns of potentially different types.

# %%
# Creating DataFrame from dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [50000, 60000, 70000, 55000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# 3    Diana   28     Paris   55000

# %%
# From list of lists
data = [['Alice', 25], ['Bob', 30], ['Charlie', 35]]
df = pd.DataFrame(data, columns=['Name','Age'])
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# From NumPy array
arr = np.array([[1,2,3], [4,5,6]])
df = pd.DataFrame(arr, columns=['A','B','C'])
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# ### DataFrame Properties

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [50000, 60000, 70000, 55000]
}
df = pd.DataFrame(data)
print(df)

# print(df.shape)        # Output: (4, 4) - (rows, columns)
# print('--'*30)
# print(df.size)         # Output: 16 - total elements
# print('--'*30)
# print(df.columns)      # Output: Index(['Name', 'Age', 'City', 'Salary'])
# print('--'*30)
# print(df.index)        # Output: RangeIndex(start=0, stop=4, step=1)
# print('--'*30)
# print(df.dtypes)       # Data types of each column
# print('--'*30)
# print(df.info())       # Summary information
# print('--'*30)
# print(df.describe())   # Statistical summary
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# 3    Diana   28     Paris   55000

# %% [markdown]
# ## DataFrame Basics and Inspection
#
# ### Inspecting Data
#
# Quickly understand your dataset using inspection functions:

# %%
print(df.shape)  # Output: (4, 4) - (rows, columns)
# Out:
# (4, 4)

# %%
print(df.size) # Output: 16 - total elements
# Out:
# 16

# %%
print(df.columns) # Output: Index(['Name', 'Age', 'City',
# Out:
# Index(['Name', 'Age', 'City', 'Salary'], dtype='str')

# %%
print(df.index) # Output: RangeIndex(start=0, stop=4, step=1)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(df.dtypes)  # Data types of each column
# Out:
# Name        str
# Age       int64
# City        str
# Salary    int64
# dtype: object

# %%
print(df.info()) # Summary information
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   Age     4 non-null      int64
#  2   City    4 non-null      str
#  3   Salary  4 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 304.0 bytes
# None

# %%
print(df.describe())  # Statistical summary
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   29.500000  58750.000000
# std     4.203173   8539.125638
# min    25.000000  50000.000000
# 25%    27.250000  53750.000000
# 50%    29.000000  57500.000000
# 75%    31.250000  62500.000000
# max    35.000000  70000.000000

# %% [markdown]
# ### Index & Columns Overview
#
# Explore DataFrame components:

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [50000, 60000, 70000, 55000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# 3    Diana   28     Paris   55000

# %%
# view index

print(df.index)  # Output: RangeIndex(start=0, stop=4, step=1)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(df.index.tolist())  # [0, 1, 2, 3]
# Out:
# [0, 1, 2, 3]

# %%
# View columns
print(df.columns)  # Output: Index(['Name', 'Age', 'City', 'Salary'])
# Out:
# Index(['Name', 'Age', 'City', 'Salary'], dtype='str')

# %%
# columns in list
print(df.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Name', 'Age', 'City', 'Salary'], dtype='str')>

# %%
# Underlying NumPy data
print(df.values)   # Returns NumPy array
# Out:
# [['Alice' 25 'New York' 50000]
#  ['Bob' 30 'London' 60000]
#  ['Charlie' 35 'Tokyo' 70000]
#  ['Diana' 28 'Paris' 55000]]

# %%
# Check if index/columns are unique
print(df.index.is_unique)  # True
print(df.columns.is_unique) # True
# Out:
# True
# True

# %% [markdown]
# ### Renaming Columns

# %%
# Rename single column

df = df.rename(columns = {'Age':'Years'})
print(df.columns)  # ['Name', 'Years', 'City', 'Salary']
# Out:
# Index(['Name', 'Years', 'City', 'Salary'], dtype='str')

# %%
# Rename multiple columns

df = df.rename(columns={
    'Name':'Full Name',
    'City':'Location',
    'Salary':'Income'
})
print(df.columns)
# Out:
# Index(['Full Name', 'Years', 'Location', 'Income'], dtype='str')

# %%
# Rename using mapper function
df = df.rename(columns=str.lower)  # Convert to lowercase
print(df.columns)
df = df.rename(columns=str.upper)  # Convert to uppercase
print(df.columns)
# Out:
# Index(['full name', 'years', 'location', 'income'], dtype='str')
# Index(['FULL NAME', 'YEARS', 'LOCATION', 'INCOME'], dtype='str')

# %%
df
# Out:
#   FULL NAME  YEARS  LOCATION  INCOME
# 0     Alice     25  New York   50000
# 1       Bob     30    London   60000
# 2   Charlie     35     Tokyo   70000
# 3     Diana     28     Paris   55000

# %%
# In-place renaming
df.rename(columns={'YEARS':'AGE'}, inplace=True)  # affect permanently
print(df.columns)
# Out:
# Index(['FULL NAME', 'AGE', 'LOCATION', 'INCOME'], dtype='str')

# %%
# Out:
#   FULL NAME  AGE  LOCATION  INCOME
# 0     Alice   25  New York   50000
# 1       Bob   30    London   60000
# 2   Charlie   35     Tokyo   70000
# 3     Diana   28     Paris   55000

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [50000, 60000, 70000, 55000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# 3    Diana   28     Paris   55000

# %% [markdown]
# ### Setting and Resetting Index

# %%
# Set a column as index
df_indexed = df.set_index('Name')
print(df_indexed)
# Out:
#          Age      City  Salary
# Name
# Alice     25  New York   50000
# Bob       30    London   60000
# Charlie   35     Tokyo   70000
# Diana     28     Paris   55000

# %%
# Reset index (move index back to column)
df_reset = df_indexed.reset_index()
print(df_reset)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# 3    Diana   28     Paris   55000

# %%
# Reset index without keeping old index as column

df_reset = df_indexed.reset_index(drop=True)
print(df_reset)
# Out:
#    Age      City  Salary
# 0   25  New York   50000
# 1   30    London   60000
# 2   35     Tokyo   70000
# 3   28     Paris   55000

# %%
# Set multiple columns as index
print(df)
print('--'*30)

df_multi = df.set_index(['City', 'Name'])
print(df_multi)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# 3    Diana   28     Paris   55000
# ------------------------------------------------------------
#                   Age  Salary
# City     Name
# New York Alice     25   50000
# London   Bob       30   60000
# Tokyo    Charlie   35   70000
# Paris    Diana     28   55000

# %% [markdown]
# ### Basic Attributes Recap
# Quick reference for core attributes:

# %% [markdown]
# ```python
# # Structure
# df.shape          # (rows, columns)
# df.size           # Total elements
# df.ndim           # Number of dimensions
#
# # Components
# df.columns        # Column names
# df.index          # Row index
# df.values         # NumPy array
#
#
# # Data types
# df.dtypes         # Data type per column
# df.dtypes.value_counts()  # Count of each data type
#
# # Memory usage
# df.memory_usage()  # Memory usage per column
# df.memory_usage(deep=True)  # Deep memory usage (includes objects)

# %% [markdown]
# ## Reading and Writing Data
# ### Reading CSV Files

# %% [markdown]
# ```python
# # Read CSV
# df = pd.read_csv('data.csv')
#
# # with options
# df = pd.read_csv('data.csv',
#                  sep=',',                    # Separator
#                  header=0,                   # Row to use as header
#                  index_col=0,                # Column to use as index
#                  na_values=['NA', 'N/A'],    # Values to treat as NaN
#                  nrows=1000)                 # Read only first 1000 rows
#
#
# # Read with specific columns
# df = pd.read_csv('data.csv', usecols=['Name', 'Age', Salary])
# print(df)

# %% [markdown]
# ### Reading Other Formats

# %% [markdown]
# ```python
# # Excel
# df = pd.read_escel(r'data.xlsx', sheet_name='Sheet1')
#
# # JSON
# df = pd.read_json(f'data.json')
#
# # HTML tables
# df = pd.read_html(f'https://example.com/table.html')[0]
#
# # SQL
# import sqlite3
# conn = sqlite3.connect('database.db')
# df = read_sql_query('SELECT * FROM table', conn)

# %% [markdown]
# ### Writing Data

# %% [markdown]
# ```python
#
# # Write to CSV
# df.to_csv('output.csv', index=False)
#
# # Write to Excel
# df.to_excel('output.xlsx', sheet_name='Data', index=False)
#
# # Write to json
# df.to_json('output.json', orient='records')
#
# # Write to sql
# df.to_sql('table_na,e',conn, if_exists='replace', index=False)
#
# ```

# %% [markdown]
# ## Data Selection and Filtering
# ### Selecting Columns

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# 3    Diana   28     Paris   55000

# %%
# Single column (returns Series)
ages = df['Age']
print(ages)

# Multiple columns (returns DataFrame)
subset = df[['Name', 'Age']]
print('\n',subset)
# Out:
# 0    25
# 1    30
# 2    35
# 3    28
# Name: Age, dtype: int64
#
#        Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    Diana   28

# %% [markdown]
# ### Selecting Rows

# %%
# By index  - iloc[]
first_row = df.iloc[0] # First row
first_three = df.iloc[:3]  # First 3 rows
print(first_row)
print('--'*30)
print(first_three)
# Out:
# Name         Alice
# Age             25
# City      New York
# Salary       50000
# Name: 0, dtype: object
# ------------------------------------------------------------
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000

# %%
# By label - loc[]
row = df.loc[0]  # Row with index 0
print(row)
# Out:
# Name         Alice
# Age             25
# City      New York
# Salary       50000
# Name: 0, dtype: object

# %%
# First/last n rows
head = df.head(3)             # First 3 rows
tail = df.tail(3)             # Last 3 rows

print(head)
print('--'*30, tail)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# ------------------------------------------------------------       Name  Age    City  Salary
# 1      Bob   30  London   60000
# 2  Charlie   35   Tokyo   70000
# 3    Diana   28   Paris   55000

# %% [markdown]
# ### Filtering

# %%
# Boolean indexing
young = df[df['Age']<30]
print(young)
# Out:
#     Name  Age      City  Salary
# 0  Alice   25  New York   50000
# 3  Diana   28     Paris   55000

# %%
# Multiple conditions
filtered = df[(df['Age']>25) & (df['Salary']>55000)]
print(filtered)
# Out:
#       Name  Age    City  Salary
# 1      Bob   30  London   60000
# 2  Charlie   35   Tokyo   70000

# %%
# Using query method
filtered = df.query('Age >25 and Salary >55000')
print(filtered)
# Out:
#       Name  Age    City  Salary
# 1      Bob   30  London   60000
# 2  Charlie   35   Tokyo   70000

# %%
# isin() method
cities = ['New York', 'London']
filtered = df[df['City'].isin(cities)]
print(filtered)
# Out:
#     Name  Age      City  Salary
# 0  Alice   25  New York   50000
# 1    Bob   30    London   60000

# %% [markdown]
# ### iloc vs loc

# %%
# iloc: Integer position-based indexing
print(df.iloc[0, 1])  # Row 0, Column 1
print('--'*20)
print(df.iloc[:3, 1:3])   # Rows 0-2, Columns 1-2
print('--'*20)

# loc: Label-based indexing
print(df.loc[0, 'Age'])   # Row with index 0, column 'Age'
print('--'*20)
print(df.loc[:2, 'Name':'City'])   # Rows 0-2, columns Name to City
# Out:
# 25
# ----------------------------------------
#    Age      City
# 0   25  New York
# 1   30    London
# 2   35     Tokyo
# ----------------------------------------
# 25
# ----------------------------------------
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Tokyo

# %% [markdown]
# ## Data Cleaning
#
# ### Handling Missing Values
#
# Detect missing entries and handle them appropriately:

# %% [markdown]
# **Check for missing values**
# ```python
# print(df.isnull)   # Boolean DataFrame (True where NaN)
# print(df.isna())   # Same as isnull()
# print(df.isnull().sum())  # Count missing per column
# print(df.isna().sum())    # same
# print(df.isnull().any())  # True if any missing in column
# print(df.isnull().any().any()) # True if any missing in entire Dataframe
#
# # Drop missing values
# df_clean = df.dropna()  # default axis=0. Drop rows with any NaN
# df_clean = df.dropna(axis=1)  # Drop columns with any NaN
# df_clean = df.dropna(subset=['Age'])  # Drop rows where Age is NaN
# df_clean = df.dropna(how='all')  # Drop rows where ALL values are NaN
#
# # Fill missing values
# df_filled = df.fillna(0)  # Fill with constant (0)
# df_filled = df.fillna({'Age':0, 'Salary':50000}) # Fill different columns with different values
# df_filled = df.fillna(df.mean()) # Fill with mean (numeric columns only)
# df_filled = df['Age'].fillna(df['Age'].mean()) # Fill specific column with its mean
# df_filled = df.fillna(df.median()) # Fill with median
# df_filled = df.fillna(df.mode().iloc[0])  # Fill with mode
#
# df_ffill = df.fillna(method='ffill') # Forward fill (use previous value)
# df_bfill = df.fillna(method='bfill') # Backward fill (use next value)
# df_ffill_limit = df.fillna(method='ffill', limit=2) # Limit forward fill to 2 consecutive NaNs
#
# # Interpolation
# df_interp = df.interpolate() # Linear Interpolation

# %% [markdown]
# ### Handling Duplicates

# %% [markdown]
# ```python
# # Check for duplicates
# print(df.duplicated()) # Boolean Series
# print(df.duplicated().sum())  # Count duplicates
#
# # Drop duplicates
# df_unique = df.drop_duplicates()# Drop all duplicates
# df_unique = df.drop_duplicates(subset=['Name']) # Drop based on column

# %%
import pandas as pd
import numpy as np
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [50000, 60000, 70000, 55000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Tokyo   70000
# 3    Diana   28     Paris   55000

# %% [markdown]
# ### Changing Data Types (astype)
#
# Convert columns to correct types for data compatibility:

# %% [markdown]
# ```python
# # Check data types
# print(df.dtypes)
#
# # Convert to integer
# df['Age'] = df['Age'].astype(int)
# df['Age'] = df['Age'].astype('int64')
#
# # Convert to float
# df['Salary'] = df['Salary'].astype(float)
# df['Salary'] = df['Salary'].astype('float64')
#
# # Convert to string
# df['Name'] = df['Name'].astype(str)
# df['Name'] = df['Name'].astype('string')
#
# # Convert to category (saves memory for repeated values)
# df['City'] = df['City'].astype('category')
# print(df['City'].cat.categories)   # view categories
#
# # Convert to datetime
# df['Date'] = pd.to_datetime(df['Date'])
# df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')  # With format
#
# # Convert to boolean
# df['IsActive'] = df['isActive'].astype(bool)
#
#
# # Convert multiple columns at once
# df[['Age', 'Salary']] = df[['Age', 'Salary']].astype(float)
#
# # Handle errors during conversion
# df['Age'] = pd.to_numeric(df['Age'], errors='coerce') # Convert invalid to NaN
# df['Age'] = pd.to_numeric(df['Age'], errors='ignore') # Leave invalid as-is

# %% [markdown]
# ### Replacing Values (replace)
# Clean or fix specific data points and typos:

# %%
df
# Out:
#       Name   Age      City   Salary
# 0    Alice  25.0  New York  50000.0
# 1      Bob  30.0    London  60000.0
# 2  Charlie  35.0     Tokyo  70000.0
# 3    Diana  28.0     Paris  55000.0

# %%
# Replace single value
df['City'] = df['City'].replace('New York', 'NYC')

# Replace multiple values
# df['City'] = df['City'].replace(['New York', 'London'], ['NYC', 'LON'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Replace single value
# ----> 2 df['City'] = df['City'].replace('New York', 'NYC')
#       3
#       4 # Replace multiple values
#       5 # df['City'] = df['City'].replace(['New York', 'London'], ['NYC', 'LON'])
#
# File c:\Users\RowTECH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:7850, in NDFrame.replace(self, to_replace, value, inplace, regex)
#    7846                         value=value,
#    7847                         inplace=inplace,
#    7848                     )
#    7849                 else:
# -> 7850                     new_data = self._mgr.replace(
#    7851                         to_replace=to_replace, value=value, inplace=inplace
#    7852                     )
#    7853             else:
#
# File c:\Users\RowTECH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:505, in BaseBlockManager.replace(self, to_replace, value, inplace)
#     503 assert not lib.is_list_like(to_replace)
#     504 assert not lib.is_list_like(value)
# --> 505 return self.apply(
#     506     "replace",
#     507     to_replace=to_replace,
#     508     value=value,
#     509     inplace=inplace,
#     510 )
#
# File c:\Users\RowTECH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\RowTECH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\blocks.py:711, in Block.replace(self, to_replace, value, inplace, mask)
#     707 elif self._can_hold_element(value) or (self.dtype == "string" and is_re(value)):
#     708     # TODO(CoW): Maybe split here as well into columns where mask has True
#     709     # and rest?
#     710     blk = self._maybe_copy(inplace)
# --> 711     putmask_inplace(blk.values, mask, value)
#     712     return [blk]
#     714 elif self.ndim == 1 or self.shape[0] == 1:
#
# File c:\Users\RowTECH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\array_algos\putmask.py:57, in putmask_inplace(values, mask, value)
#      55         values[mask] = value[mask]
#      56     else:
# ---> 57         values[mask] = value
#      58 else:
#      59     # GH#37833 np.putmask is more performant than __setitem__
#      60     np.putmask(values, mask, value)
#
# File c:\Users\RowTECH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arrays\_mixins.py:272, in NDArrayBackedExtensionArray.__setitem__(self, key, value)
#     269     raise ValueError("Cannot modify read-only array")
#     271 key = check_array_indexer(self, key)
# --> 272 value = self._validate_setitem_value(value)
#     273 self._ndarray[key] = value
#
# File c:\Users\RowTECH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arrays\categorical.py:1653, in Categorical._validate_setitem_value(self, value)
#    1651     return self._validate_listlike(value)
#    1652 else:
# -> 1653     return self._validate_scalar(value)
#
# File c:\Users\RowTECH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arrays\categorical.py:1678, in Categorical._validate_scalar(self, fill_value)
#    1676     fill_value = self._unbox_scalar(fill_value)
#    1677 else:
# -> 1678     raise TypeError(
#    1679         "Cannot setitem on a Categorical with a new "
#    1680         f"category ({fill_value}), set the categories first"
#    1681     ) from None
#    1682 return fill_value
#
# TypeError: Cannot setitem on a Categorical with a new category (NYC), set the categories first
